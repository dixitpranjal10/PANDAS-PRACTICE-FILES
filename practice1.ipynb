# %%
import pandas as pd 
import numpy as np

# %%
df=pd.DataFrame(np.random.rand(100,10), index=np.arange(100))
df.columns = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df
# Out:
#            A         B         C         D         E         F         G  \
# 0   0.328180  0.688860  0.544959  0.235673  0.770454  0.528274  0.882378
# 1   0.133181  0.070962  0.764513  0.260051  0.996807  0.823694  0.209215
# 2   0.648782  0.193158  0.477504  0.843385  0.529131  0.516124  0.109892
# 3   0.946699  0.490310  0.415478  0.745460  0.457492  0.272607  0.167539
# 4   0.789248  0.757067  0.055231  0.015347  0.073392  0.234223  0.801552
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.969000  0.093411  0.542343  0.838330  0.537839  0.055392  0.313356
# 96  0.418811  0.467655  0.546181  0.529235  0.492820  0.098205  0.705163
# 97  0.808406  0.247143  0.637193  0.281263  0.281078  0.157486  0.335595
# 98  0.407043  0.057384  0.475514  0.776421  0.874226  0.703241  0.393264
# 99  0.241780  0.657350  0.982158  0.034494  0.686818  0.075290  0.384147
#
#            H         I         J
# 0   0.179645  0.095799  0.839610
# ...

# %%
df2=pd.DataFrame(np.random.rand(100,5), index=np.arange(100))
df2.columns = ['a', 'b', 'c', 'd', 'e']

# %%
df2
# Out:
#            a         b         c         d         e
# 0   0.949766  0.605752  0.244466  0.316621  0.712721
# 1   0.169066  0.861899  0.968196  0.008760  0.845729
# 2   0.219622  0.097673  0.093574  0.422489  0.022168
# 3   0.433301  0.615102  0.135393  0.049810  0.867731
# 4   0.524703  0.204810  0.697002  0.370943  0.633316
# ..       ...       ...       ...       ...       ...
# 95  0.596436  0.764050  0.139621  0.523245  0.786922
# 96  0.927885  0.253035  0.138231  0.452707  0.263191
# 97  0.664238  0.340016  0.688608  0.016978  0.779870
# 98  0.512853  0.844237  0.820215  0.251282  0.987368
# 99  0.568999  0.142312  0.366654  0.860410  0.582660
#
# [100 rows x 5 columns]

# %%
#itrrows---------------------------------------
for index, a in df2.iterrows():
    print(index , '-' , a)
# Out:
# 0 - a    0.949766
# b    0.605752
# c    0.244466
# d    0.316621
# e    0.712721
# Name: 0, dtype: float64
# 1 - a    0.169066
# b    0.861899
# c    0.968196
# d    0.008760
# e    0.845729
# Name: 1, dtype: float64
# 2 - a    0.219622
# b    0.097673
# c    0.093574
# d    0.422489
# e    0.022168
# Name: 2, dtype: float64
# 3 - a    0.433301
# b    0.615102
# c    0.135393
# d    0.049810
# e    0.867731
# Name: 3, dtype: float64
# 4 - a    0.524703
# b    0.204810
# c    0.697002
# d    0.370943
# e    0.633316
# Name: 4, dtype: float64
# 5 - a    0.431529
# b    0.325125
# c    0.427998
# d    0.138550
# e    0.152658
# Name: 5, dtype: float64
# 6 - a    0.774206
# b    0.382946
# c    0.307168
# d    0.257791
# e    0.339583
# Name: 6, dtype: float64
# 7 - a    0.829991
# b    0.595554
# c    0.409543
# d    0.972526
# e    0.241472
# Name: 7, dtype: float64
# 8 - a    0.754486
# b    0.782354
# c    0.204095
# d    0.785289
# e    0.486104
# Name: 8, dtype: float64
# ...

# %%
#itertuples------------------------------------------------------------------------------------------------------
for a in df2.itertuples():
    print (a)
# Out:
# Pandas(Index=0, a=0.9497661337959379, b=0.6057523950598827, c=0.24446568666271828, d=0.3166207558616225, e=0.7127207015105492)
# Pandas(Index=1, a=0.1690664461179613, b=0.8618986111201827, c=0.968195987673211, d=0.008759658733171638, e=0.845728904169109)
# Pandas(Index=2, a=0.2196218800521087, b=0.09767344360336516, c=0.09357356329476196, d=0.4224893846851293, e=0.022168467854976504)
# Pandas(Index=3, a=0.4333010986365333, b=0.6151021476718536, c=0.13539339798125227, d=0.049809943560725656, e=0.8677306424695735)
# Pandas(Index=4, a=0.5247025350975876, b=0.20481024475988419, c=0.6970024943171484, d=0.37094284009037626, e=0.6333158740655356)
# Pandas(Index=5, a=0.4315292226514813, b=0.3251251767454968, c=0.42799768050883646, d=0.13854969105347625, e=0.15265842026993015)
# Pandas(Index=6, a=0.7742057495979864, b=0.382946487866079, c=0.30716828848201894, d=0.2577907416383457, e=0.3395832432763589)
# ...

# %%
#newdf = df.merge(df2, on = 'name')
newdf = pd.merge(df, df2, left_index=True, right_index=True)

# %%
newdf
# Out:
#            A         B         C         D         E         F         G  \
# 0   0.328180  0.688860  0.544959  0.235673  0.770454  0.528274  0.882378
# 1   0.133181  0.070962  0.764513  0.260051  0.996807  0.823694  0.209215
# 2   0.648782  0.193158  0.477504  0.843385  0.529131  0.516124  0.109892
# 3   0.946699  0.490310  0.415478  0.745460  0.457492  0.272607  0.167539
# 4   0.789248  0.757067  0.055231  0.015347  0.073392  0.234223  0.801552
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.969000  0.093411  0.542343  0.838330  0.537839  0.055392  0.313356
# 96  0.418811  0.467655  0.546181  0.529235  0.492820  0.098205  0.705163
# 97  0.808406  0.247143  0.637193  0.281263  0.281078  0.157486  0.335595
# 98  0.407043  0.057384  0.475514  0.776421  0.874226  0.703241  0.393264
# 99  0.241780  0.657350  0.982158  0.034494  0.686818  0.075290  0.384147
#
#            H         I         J         a         b         c         d  \
# ...

# %%
df3 = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar'],
    'B': [1, 2, 3, 4, 5, 6],
    'C': [7, 8, 9, 10, 11, 12]
})

# %%
grouped = df3.groupby('A')

# %%
sum= grouped.sum()

# %%
sum
# Out:
#       B   C
# A
# bar  12  30
# foo   9  27

# %%
df['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot(column='A', grid=False)
# Out:
# <Axes: >

# %%
# Convert a string to a datetime object
date_string = '2023-07-17'
dateTime = pd.to_datetime(date_string)
print(dateTime)
# Out:
# 2023-07-17 00:00:00
